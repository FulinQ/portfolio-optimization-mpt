# %%
import pandas as pd
import os
os.chdir('/Users/fulinq/Documents/KMITL/FinancialEngineering/Y5/STOCHASTIC OPTIMIZATION/Project/MPT')

# %%
price_df = pd.read_excel('28AUG.xlsx', index_col=0)
price_df = price_df.sort_index()
price_df = price_df.ffill()
price_df = price_df.sort_index(ascending=False)
price_df
# Out:
#              KKP MP  KKP DIVIDEND  KKP CorePath Balanced  KKP ACT FIXED  \
# Date
# 2026-08-28  12.9752       14.2669                18.2555        12.4779
# 2026-08-27  12.9747       14.2528                18.2555        12.4812
# 2026-08-26  12.9746       14.3069                18.2555        12.4825
# 2026-08-25  12.9744       14.1797                18.2479        12.4792
# 2026-08-24  12.9741       14.2141                18.1946        12.4762
# ...             ...           ...                    ...            ...
# 2008-09-16  10.0062           NaN                    NaN            NaN
# 2008-09-15  10.0053           NaN                    NaN            NaN
# 2008-09-12  10.0024           NaN                    NaN            NaN
# 2008-09-11  10.0016           NaN                    NaN            NaN
# 2008-09-10  10.0007           NaN                    NaN            NaN
#
#             KKP SM CAP  KKP CorePath Extra  KKP SEMICON-H  KKP INCOME-H  \
# Date
# ...

# %%
import numpy as np

log_return_df = np.log(price_df / price_df.shift(-1))*np.sqrt(252)
log_return_df = log_return_df.dropna(how='all')
log_return_df
# Out:
#               KKP MP  KKP DIVIDEND  KKP CorePath Balanced  KKP ACT FIXED  \
# Date
# 2026-08-28  0.000612      0.015697               0.000000      -0.004198
# 2026-08-27  0.000122     -0.060142               0.000000      -0.001653
# 2026-08-26  0.000245      0.141768               0.006610       0.004197
# 2026-08-25  0.000367     -0.038465               0.046435       0.003817
# 2026-08-24  0.000734     -0.084985              -0.025369      -0.002163
# ...              ...           ...                    ...            ...
# 2008-09-17  0.001269           NaN                    NaN            NaN
# 2008-09-16  0.001428           NaN                    NaN            NaN
# 2008-09-15  0.004602           NaN                    NaN            NaN
# 2008-09-12  0.001270           NaN                    NaN            NaN
# 2008-09-11  0.001429           NaN                    NaN            NaN
#
#             KKP SM CAP  KKP CorePath Extra  KKP SEMICON-H  KKP INCOME-H  \
# Date
# ...

# %%
log_return_df.describe()
# Out:
#             KKP MP  KKP DIVIDEND  KKP CorePath Balanced  KKP ACT FIXED  \
# count  4308.000000   3452.000000            2850.000000    2645.000000
# mean      0.000959      0.001635               0.002284       0.001329
# std       0.001074      0.160720               0.073087       0.007066
# min      -0.001948     -1.920908              -0.818937      -0.072857
# 25%       0.000392     -0.072648              -0.028960      -0.001471
# 50%       0.000680      0.007188               0.001998       0.001369
# 75%       0.001217      0.088322               0.037757       0.004176
# max       0.035867      1.344023               0.520138       0.056246
#
#         KKP SM CAP  KKP CorePath Extra  KKP SEMICON-H  KKP INCOME-H  \
# count  2373.000000         1806.000000    1245.000000   1116.000000
# mean      0.002739            0.002474       0.013834      0.000687
# std       0.175196            0.115080       0.376709      0.061991
# ...
