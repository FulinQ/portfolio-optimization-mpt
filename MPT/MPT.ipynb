# %%
import pandas as pd
import os
os.chdir('/Users/fulinq/Documents/KMITL/FinancialEngineering/Y5/STOCHASTIC OPTIMIZATION/Project/MPT')

# %%
price_df = pd.read_excel('28AUG.xlsx', index_col=0)
price_df = price_df.fillna(method='ffill', axis=0)
price_df
# Out:
# /var/folders/rc/w7r40l35143bxwkzfxdygctc0000gn/T/ipykernel_42308/1764115462.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   price_df = price_df.fillna(method='ffill')
#              KKP MP  KKP DIVIDEND  KKP CorePath Balanced  KKP ACT FIXED  \
# Date
# 2026-08-28  12.9752       14.2669                    NaN        12.4779
# 2026-08-27  12.9747       14.2528                    NaN        12.4812
# 2026-08-26  12.9746       14.3069                18.2555        12.4825
# 2026-08-25  12.9744       14.1797                18.2479        12.4792
# 2026-08-24  12.9741       14.2141                18.1946        12.4762
# ...             ...           ...                    ...            ...
# 2008-09-16  10.0062        9.9982                12.1157         9.9999
# 2008-09-15  10.0053        9.9982                12.1157         9.9999
# ...
